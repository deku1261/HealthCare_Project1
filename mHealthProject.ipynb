# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv("../HealthCare_Project1/COVID-19_Vaccinations_in_the_United_States_County.csv",low_memory=False)

# %%
df.describe()
# Out:
#           MMWR_week  Completeness_pct  Administered_Dose1_Pop_Pct  \
# count  1.959498e+06      1.953847e+06                1.935559e+06
# mean   2.350954e+01      8.233917e+01                3.947434e+01
# std    1.547179e+01      3.027798e+01                2.493837e+01
# min    1.000000e+00      0.000000e+00                0.000000e+00
# 25%    1.000000e+01      9.020000e+01                1.920000e+01
# 50%    2.100000e+01      9.500000e+01                4.360000e+01
# 75%    3.600000e+01      9.760000e+01                5.700000e+01
# max    5.300000e+01      1.000000e+02                1.000000e+02
#
#        Administered_Dose1_Recip_5PlusPop_Pct  \
# count                          748925.000000
# mean                               60.610848
# std                                18.067553
# min                                 0.000000
# 25%                                50.700000
# 50%                                60.000000
# 75%                                71.000000
# max                                99.900000
#
#        Administered_Dose1_Recip_12PlusPop_Pct  \
# count                            1.911158e+06
# mean                             4.444532e+01
# std                              2.839977e+01
# min                              0.000000e+00
# 25%                              1.910000e+01
# 50%                              5.040000e+01
# 75%                              6.550000e+01
# max                              1.000000e+02
#
#        Administered_Dose1_Recip_18PlusPop_Pct  \
# count                            1.929554e+06
# mean                             4.625624e+01
# std                              2.895874e+01
# min                              0.000000e+00
# 25%                              2.080000e+01
# 50%                              5.310000e+01
# 75%                              6.790000e+01
# max                              1.000000e+02
#
#        Administered_Dose1_Recip_65PlusPop_Pct  Series_Complete_Pop_Pct  \
# count                            1.929659e+06             1.944689e+06
# mean                             6.211831e+01             3.461757e+01
# std                              3.426056e+01             2.206231e+01
# min                              0.000000e+00             0.000000e+00
# 25%                              4.120000e+01             1.600000e+01
# 50%                              7.590000e+01             3.840000e+01
# 75%                              8.910000e+01             5.050000e+01
# max                              1.000000e+02             1.000000e+02
#
#        Series_Complete_5PlusPop_Pct  Series_Complete_5to17Pop_Pct  ...  \
# count                 764099.000000                 419855.000000  ...
# mean                      53.814925                     26.961205  ...
# std                       14.729321                     16.820066  ...
# min                        0.000000                      1.300000  ...
# 25%                       44.700000                     15.300000  ...
# 50%                       52.800000                     22.300000  ...
# 75%                       62.100000                     33.400000  ...
# max                       99.900000                     95.000000  ...
#
#        Booster_Doses_18PlusVax_Pct_SVI  Booster_Doses_65PlusVax_Pct_SVI  \
# count                    419613.000000                    419613.000000
# mean                          9.176837                         8.631732
# std                           4.224785                         4.289863
# min                           1.000000                         1.000000
# 25%                           4.000000                         4.000000
# 50%                           9.000000                         9.000000
# 75%                          13.000000                        13.000000
# max                          16.000000                        16.000000
#
#        Booster_Doses_Vax_Pct_UR_Equity  Booster_Doses_12PlusVax_Pct_UR_Equity  \
# count                    419593.000000                          419593.000000
# mean                          5.456032                               5.520349
# std                           2.162463                               2.154841
# min                           1.000000                               1.000000
# 25%                           3.000000                               4.000000
# 50%                           6.000000                               6.000000
# 75%                           7.000000                               7.000000
# max                           8.000000                               8.000000
#
#        Booster_Doses_18PlusVax_Pct_UR_Equity  \
# count                          419593.000000
# mean                                5.634319
# std                                 2.143578
# min                                 1.000000
# 25%                                 4.000000
# 50%                                 6.000000
# 75%                                 8.000000
# max                                 8.000000
#
#        Booster_Doses_65PlusVax_Pct_UR_Equity  Bivalent_Booster_5Plus_Pop_Pct  \
# count                          419408.000000                     80125.00000
# mean                                5.090079                        10.93856
# std                                 2.084874                         6.25981
# min                                 1.000000                         0.10000
# 25%                                 3.000000                         6.50000
# 50%                                 6.000000                         9.50000
# 75%                                 7.000000                        14.00000
# max                                 8.000000                        46.80000
#
#        Bivalent_Booster_12Plus_Pop_Pct  Bivalent_Booster_18Plus_Pop_Pct  \
# count                     80125.000000                     80125.000000
# mean                         11.861092                        12.709996
# std                           6.645911                         6.951557
# min                           0.100000                         0.100000
# 25%                           7.100000                         7.700000
# 50%                          10.400000                        11.200000
# 75%                          15.200000                        16.300000
# max                          51.200000                        52.900000
#
#        Bivalent_Booster_65Plus_Pop_Pct
# count                     80125.000000
# mean                         29.096659
# std                          13.861535
# min                           0.100000
# 25%                          18.900000
# 50%                          26.900000
# 75%                          37.400000
# max                          86.000000
#
# [8 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['Date', 'FIPS', 'MMWR_week', 'Recip_County', 'Recip_State',
#        'Completeness_pct', 'Administered_Dose1_Recip',
#        'Administered_Dose1_Pop_Pct', 'Administered_Dose1_Recip_5Plus',
#        'Administered_Dose1_Recip_5PlusPop_Pct',
#        'Administered_Dose1_Recip_12Plus',
#        'Administered_Dose1_Recip_12PlusPop_Pct',
#        'Administered_Dose1_Recip_18Plus',
#        'Administered_Dose1_Recip_18PlusPop_Pct',
#        'Administered_Dose1_Recip_65Plus',
#        'Administered_Dose1_Recip_65PlusPop_Pct', 'Series_Complete_Yes',
#        'Series_Complete_Pop_Pct', 'Series_Complete_5Plus',
#        'Series_Complete_5PlusPop_Pct', 'Series_Complete_5to17',
#        'Series_Complete_5to17Pop_Pct', 'Series_Complete_12Plus',
#        'Series_Complete_12PlusPop_Pct', 'Series_Complete_18Plus',
#        'Series_Complete_18PlusPop_Pct', 'Series_Complete_65Plus',
#        'Series_Complete_65PlusPop_Pct', 'Booster_Doses',
#        'Booster_Doses_Vax_Pct', 'Booster_Doses_5Plus',
#        'Booster_Doses_5Plus_Vax_Pct', 'Booster_Doses_12Plus',
#        'Booster_Doses_12Plus_Vax_Pct', 'Booster_Doses_18Plus',
#        'Booster_Doses_18Plus_Vax_Pct', 'Booster_Doses_50Plus',
#        'Booster_Doses_50Plus_Vax_Pct', 'Booster_Doses_65Plus',
#        'Booster_Doses_65Plus_Vax_Pct', 'Second_Booster_50Plus',
#        'Second_Booster_50Plus_Vax_Pct', 'Second_Booster_65Plus',
#        'Second_Booster_65Plus_Vax_Pct', 'SVI_CTGY',
#        'Series_Complete_Pop_Pct_SVI', 'Series_Complete_5PlusPop_Pct_SVI',
#        'Series_Complete_5to17Pop_Pct_SVI', 'Series_Complete_12PlusPop_Pct_SVI',
#        'Series_Complete_18PlusPop_Pct_SVI',
#        'Series_Complete_65PlusPop_Pct_SVI', 'Metro_status',
#        'Series_Complete_Pop_Pct_UR_Equity',
#        'Series_Complete_5PlusPop_Pct_UR_Equity',
#        'Series_Complete_5to17Pop_Pct_UR_Equity',
#        'Series_Complete_12PlusPop_Pct_UR_Equity',
#        'Series_Complete_18PlusPop_Pct_UR_Equity',
#        'Series_Complete_65PlusPop_Pct_UR_Equity', 'Booster_Doses_Vax_Pct_SVI',
#        'Booster_Doses_12PlusVax_Pct_SVI', 'Booster_Doses_18PlusVax_Pct_SVI',
#        'Booster_Doses_65PlusVax_Pct_SVI', 'Booster_Doses_Vax_Pct_UR_Equity',
#        'Booster_Doses_12PlusVax_Pct_UR_Equity',
#        'Booster_Doses_18PlusVax_Pct_UR_Equity',
#        'Booster_Doses_65PlusVax_Pct_UR_Equity', 'Census2019',
#        'Census2019_5PlusPop', 'Census2019_5to17Pop', 'Census2019_12PlusPop',
#        'Census2019_18PlusPop', 'Census2019_65PlusPop',
#        'Bivalent_Booster_5Plus', 'Bivalent_Booster_5Plus_Pop_Pct',
#        'Bivalent_Booster_12Plus', 'Bivalent_Booster_12Plus_Pop_Pct',
#        'Bivalent_Booster_18Plus', 'Bivalent_Booster_18Plus_Pop_Pct',
#        'Bivalent_Booster_65Plus', 'Bivalent_Booster_65Plus_Pop_Pct'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1959498 entries, 0 to 1959497
# Data columns (total 80 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   Date                                     object
#  1   FIPS                                     object
#  2   MMWR_week                                int64
#  3   Recip_County                             object
#  4   Recip_State                              object
#  5   Completeness_pct                         float64
#  6   Administered_Dose1_Recip                 object
#  7   Administered_Dose1_Pop_Pct               float64
#  8   Administered_Dose1_Recip_5Plus           object
#  9   Administered_Dose1_Recip_5PlusPop_Pct    float64
#  10  Administered_Dose1_Recip_12Plus          object
#  11  Administered_Dose1_Recip_12PlusPop_Pct   float64
#  12  Administered_Dose1_Recip_18Plus          object
#  13  Administered_Dose1_Recip_18PlusPop_Pct   float64
#  14  Administered_Dose1_Recip_65Plus          object
#  15  Administered_Dose1_Recip_65PlusPop_Pct   float64
#  16  Series_Complete_Yes                      object
#  17  Series_Complete_Pop_Pct                  float64
#  18  Series_Complete_5Plus                    object
#  19  Series_Complete_5PlusPop_Pct             float64
#  20  Series_Complete_5to17                    object
#  21  Series_Complete_5to17Pop_Pct             float64
#  22  Series_Complete_12Plus                   object
#  23  Series_Complete_12PlusPop_Pct            float64
#  24  Series_Complete_18Plus                   object
#  25  Series_Complete_18PlusPop_Pct            float64
#  26  Series_Complete_65Plus                   object
#  27  Series_Complete_65PlusPop_Pct            float64
#  28  Booster_Doses                            object
#  29  Booster_Doses_Vax_Pct                    float64
#  30  Booster_Doses_5Plus                      object
#  31  Booster_Doses_5Plus_Vax_Pct              float64
#  32  Booster_Doses_12Plus                     object
#  33  Booster_Doses_12Plus_Vax_Pct             float64
#  34  Booster_Doses_18Plus                     object
#  35  Booster_Doses_18Plus_Vax_Pct             float64
#  36  Booster_Doses_50Plus                     object
#  37  Booster_Doses_50Plus_Vax_Pct             float64
#  38  Booster_Doses_65Plus                     object
#  39  Booster_Doses_65Plus_Vax_Pct             float64
#  40  Second_Booster_50Plus                    float64
#  41  Second_Booster_50Plus_Vax_Pct            float64
#  42  Second_Booster_65Plus                    float64
#  43  Second_Booster_65Plus_Vax_Pct            float64
#  44  SVI_CTGY                                 object
#  45  Series_Complete_Pop_Pct_SVI              float64
#  46  Series_Complete_5PlusPop_Pct_SVI         float64
#  47  Series_Complete_5to17Pop_Pct_SVI         float64
#  48  Series_Complete_12PlusPop_Pct_SVI        float64
#  49  Series_Complete_18PlusPop_Pct_SVI        float64
#  50  Series_Complete_65PlusPop_Pct_SVI        float64
#  51  Metro_status                             object
#  52  Series_Complete_Pop_Pct_UR_Equity        float64
#  53  Series_Complete_5PlusPop_Pct_UR_Equity   float64
#  54  Series_Complete_5to17Pop_Pct_UR_Equity   float64
#  55  Series_Complete_12PlusPop_Pct_UR_Equity  float64
#  56  Series_Complete_18PlusPop_Pct_UR_Equity  float64
#  57  Series_Complete_65PlusPop_Pct_UR_Equity  float64
#  58  Booster_Doses_Vax_Pct_SVI                float64
#  59  Booster_Doses_12PlusVax_Pct_SVI          float64
#  60  Booster_Doses_18PlusVax_Pct_SVI          float64
#  61  Booster_Doses_65PlusVax_Pct_SVI          float64
#  62  Booster_Doses_Vax_Pct_UR_Equity          float64
#  63  Booster_Doses_12PlusVax_Pct_UR_Equity    float64
#  64  Booster_Doses_18PlusVax_Pct_UR_Equity    float64
#  65  Booster_Doses_65PlusVax_Pct_UR_Equity    float64
#  66  Census2019                               object
#  67  Census2019_5PlusPop                      object
#  68  Census2019_5to17Pop                      object
#  69  Census2019_12PlusPop                     object
#  70  Census2019_18PlusPop                     object
#  71  Census2019_65PlusPop                     object
#  72  Bivalent_Booster_5Plus                   object
#  73  Bivalent_Booster_5Plus_Pop_Pct           float64
#  74  Bivalent_Booster_12Plus                  object
#  75  Bivalent_Booster_12Plus_Pop_Pct          float64
#  76  Bivalent_Booster_18Plus                  object
#  77  Bivalent_Booster_18Plus_Pop_Pct          float64
#  78  Bivalent_Booster_65Plus                  object
#  79  Bivalent_Booster_65Plus_Pop_Pct          float64
# dtypes: float64(46), int64(1), object(33)
# memory usage: 1.2+ GB

# %%
df.rename(
    columns={"Date": "Time"},
    inplace=True,
)
df['Time'] = pd.to_datetime(df['Time'])


q1_df = df.groupby(df['Time'])['Series_Complete_Pop_Pct'].mean()
q1_df = pd.DataFrame(q1_df)
q1_df
# Out:
#             Series_Complete_Pop_Pct
# Time
# 2020-12-13                 0.000000
# 2020-12-14                 0.000000
# 2020-12-15                 0.000000
# 2020-12-16                 0.000000
# 2020-12-17                 0.000000
# ...                             ...
# 2023-04-05                53.990702
# 2023-04-12                53.999563
# 2023-04-19                53.991888
# 2023-04-26                53.999563
# 2023-05-03                54.008643
#
# [597 rows x 1 columns]

# %%
len(df['Time'])
# Out:
# 1959498

# %%
# plt.scatter(q1_df.index,q1_df['Series_Complete_Pop_Pct'])
q1_df.plot(grid=True, color ='red')
plt.ylabel(" % of Series completion")
plt.title("Cov-19 Vaccination Series Completion", fontweight="bold")
plt.legend(loc ="best")
plt.show()

# q1_df['Date'] = pd.to_datetime(q1_df['Date'])
# plt.scatter(q1_df['Date'], q1_df['Series_Complete_Pop_Pct'])
# plt.show()

# %%
q1a_df = pd.DataFrame(df)
# Convert 'Date' column to datetime
q1a_df['Time'] = pd.to_datetime(q1a_df['Time'])

# Extract the year from 'Date' column
q1a_df['Year'] = q1a_df['Time'].dt.year

# Filter data for the years 2021, 2022, and 2023
q1a_df_yearly = q1a_df[q1a_df['Year'].isin([2021, 2022, 2023])]

# Calculate the average completion percentage for each year
yearly_completion = q1a_df_yearly.groupby('Year')['Series_Complete_Pop_Pct'].mean()

# Create bar chart
plt.bar(yearly_completion.index, yearly_completion, color="green")

# Add text annotations
for i, value in enumerate(yearly_completion):
    plt.text(yearly_completion.index[i], value, f"{value:.2f}%", ha='center', va='bottom')

plt.xlabel("Year")
plt.ylabel("% of Series completion")
plt.title("COVID-19 Vaccination Series Completion by Year", fontweight="bold")

plt.xticks(yearly_completion.index, map(int, yearly_completion.index))

# Show the plot
plt.show()
